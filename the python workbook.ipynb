# %% [markdown]
# exercise 3: Area of field

# %%
length = float(input("length of field: "))
breadth = float(input('breath of field: '))
print("there are ",length*breadth ,"/sq feet ","in acres")
# Out:
# length of field: 23
# breath of field: 6
# there are  138.0 /sq feet  in acres

# %% [markdown]
# exercise 7: sum of the first n positive integers

# %%
x = int(input("sum of first n numbers: "))
print('sum = ',x*(x+1)/2)
# Out:
# sum of first n numbers: 43
# sum =  946.0

# %% [markdown]
# exercise 10: arithmetic

# %%
a = int(input('enter the value of a : '))
b = int(input('input the value of b : '))
print('the sum of a and b: ', a+b)
print('diffrence of a and b', a-b)
print('product of a and b', a * b)
# Out:
# enter the value of a : 34
# input the value of b : 45
# the sum of a and b:  79
# diffrence of a and b -11
# product of a and b 1530

# %%
def area(len,bred):
  area = len*bred
  return area

len = eval(input('length: '))
bred = eval(input('bred: '))
print(area(len,bred))
# Out:
# length: 56
# bred: 34
# 1904

# %% [markdown]
# Function Exercises

# %% [markdown]
# exercise: 81

# %%
import math
def use_pytrem():
  a = eval(input('one shorter side: '))
  b = eval(input('second shorter side: '))
  z = math.sqrt(a*a+b*b)
  print('length of hypotenuse of right angle triangle is ',z)

use_pytrem()
# Out:
# one shorter side: 56
# second shorter side: 56
# length of hypotenuse of right angle triangle is  79.19595949289332
# 79.19595949289332
